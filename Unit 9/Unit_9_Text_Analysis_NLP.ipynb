# %%
import tweepy

# Function to extract tweets 
def get_tweets(username): 
        CONSUMER_KEY = 'OUv3sUhiBcXQf9g91x9Ayii2O'
        CONSUMER_SECRET = 'zkuQj5HnaVsFpz679U0XF54fl9lrhJKrrpqM5KFn5GuRLqEAOQ'
        OAUTH_TOKEN = '18249358-boz39qBA8cytXPhZ3WleTkmvDBSnWBri2OXGONDwv'
        OAUTH_SECRET = '1PBMhhE5FrPZoKD6Mpph5rkQAjC28TgtMqPcem1auwN9f'
          
        # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET) 
  
        # Access to user's access key and access secret 
        auth.set_access_token(OAUTH_TOKEN, OAUTH_SECRET) 
  
        # Calling api 
        api = tweepy.API(auth) 
  
        # 200 tweets to be extracted 
        number_of_tweets=200
        tweets = api.user_timeline(screen_name=username) 
  
        # Empty Array 
        tmp=[]  
  
        # create array of tweet information: username,  
        # tweet id, date/time, text 
        tweets_for_csv = [tweet.text for tweet in tweets] # CSV file created  
        for j in tweets_for_csv: 
  
            # Appending tweets to the empty array tmp 
            tmp.append(j)  
  
        # Printing the tweets 
        return(tmp)

# %%
tweetlist = get_tweets('@SyracuseU')
tweetlist[0]
# Out:
# 'RT @KatieNews4: Celebrating #CollegeColorsDay in the @news4buffalo newsroom. @zachsmalt and I are just a couple of @SyracuseU @NewhouseBDJ…'

# %%
tweetfile = open("tweetfile.txt","w") 

for tweet in tweetlist:
    tweetfile.write(tweet)
    tweetfile.write('\n\n')

tweetfile.close()

# %%
# To kill mogodprocess pgrep mongo; kill ####
import nltk
words = text.split()
import pymongo
client=pymongo.MongoClient()
client.database_names()
db=client.fbusers
db.collection_names()
coll=db.foxsports
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3e1275d4bf91> in <module>
#       1 # To kill mogodprocess pgrep mongo; kill ####
#       2 import nltk
# ----> 3 text
#       4 words = text.split()
#       5 import pymongo
#
# NameError: name 'text' is not defined

# %% [markdown]
# # From a file: Courtesy of  Ammie Dumalagan

# %%
# Courtesy of  Ammie Dumalagan
# In[2]:


file = open('tweetfile.txt', 'r')


# In[3]:


raw = file.read()

# %% [markdown]
# # Break words up into tokens

# %% [markdown]
# ## Short aside: what are tokens?
#
# - Tokens are the smallest usit of analysis in text analysis
#
# - Tokens can be either single words, bi-grams (2 word phrases), tri-grams etc.
#
# - Tokens can be any n-gram you desire but usually there are no more than 2 or 3

# %% [markdown]
# # Break the texts down into unigrams

# %%
# In[4]:


import nltk


# In[5]:


tokens = nltk.word_tokenize(raw)


# In[9]:


len(tokens)

tokens
# Out:
# ['RT',
#  '@',
#  'KatieNews4',
#  ':',
#  'Celebrating',
#  '#',
#  'CollegeColorsDay',
#  'in',
#  'the',
#  '@',
#  'news4buffalo',
#  'newsroom',
#  '.',
#  '@',
#  'zachsmalt',
#  'and',
#  'I',
#  'are',
#  'just',
#  'a',
#  'couple',
#  'of',
#  '@',
#  'SyracuseU',
#  '@',
#  'NewhouseBDJ…',
#  'RT',
#  '@',
#  'Cuse',
#  ':',
#  'Wake',
#  'up',
#  '!',
#  'It',
#  "'s",
#  '#',
#  'CollegeColorsDay',
#  '!',
#  'Wear',
#  'your',
#  "'Cuse",
#  'gear',
#  'and',
#  'rep',
#  'the',
#  'Orange',
#  '!',
#  '🍊',
#  'https',
#  ':',
#  '//t.co/u4Hpt74ZbQ',
#  'There',
#  "'s",
#  'nothing',
#  'quite',
#  'like',
#  'the',
#  'excitement',
#  'of',
#  'a',
#  'new',
#  'semester',
#  'at',
#  '#',
#  'SyracuseU',
#  '🍊',
#  'Campus',
#  'is',
#  'buzzing',
#  '!',
#  'https',
#  ':',
#  '//t.co/OqEIntmXWy',
#  'RT',
#  '@',
#  'EngineeringSU',
#  ':',
#  'First',
#  'week',
#  'of',
#  'the',
#  'fall',
#  'semester',
#  'and',
#  'class',
#  'is',
#  'in',
#  'session',
#  'with',
#  'Professor',
#  '@',
#  'TheOttoOrange',
#  '!',
#  '🍊',
#  '#',
#  'Skills',
#  '#',
#  'CoolAsIce',
#  '🎵⬆️',
#  '@',
#  'Syracus…',
#  '#',
#  'TBT',
#  'Check',
#  'out',
#  'some',
#  'of',
#  'our',
#  'favorite',
#  'photos',
#  'from',
#  '#',
#  'SUWelcome',
#  'in',
#  'our',
#  'Facebook',
#  'photo',
#  'album',
#  ':',
#  'https',
#  ':',
#  '//t.co/HxXKg90viA',
#  'https',
#  ':',
#  '//t.co/aeLTNqoAJ7',
#  'RT',
#  '@',
#  'michaelavarvis',
#  ':',
#  'The',
#  'fact',
#  'that',
#  'I',
#  'get',
#  'to',
#  'pet',
#  'dogs',
#  '3',
#  'days',
#  'a',
#  'week',
#  'in',
#  'the',
#  'Pet',
#  'Therapy',
#  'room',
#  'is',
#  'amazing',
#  '.',
#  'Thank',
#  'you',
#  '@',
#  'SyracuseU',
#  'https',
#  ':',
#  '//t.co/tfJ…',
#  'RT',
#  '@',
#  'CuseFootball',
#  ':',
#  '👀',
#  'First',
#  'look',
#  'at',
#  'our',
#  'new',
#  'unis',
#  'this',
#  'weekend',
#  '.',
#  'https',
#  ':',
#  '//t.co/OknRfF4DHV',
#  'The',
#  'Connective',
#  'Corridor',
#  ',',
#  'a',
#  'path',
#  'that',
#  'links',
#  'the',
#  'campus',
#  'community',
#  'with',
#  'downtown',
#  'Syracuse',
#  ',',
#  'gives',
#  'students',
#  'easy',
#  'access…',
#  'https',
#  ':',
#  '//t.co/O3bsILRaS3',
#  'Rolling',
#  'into',
#  'the',
#  'new',
#  'school',
#  'year',
#  'like..',
#  '@',
#  'TheOttoOrange',
#  'https',
#  ':',
#  '//t.co/lqI1JOSjTG',
#  'For',
#  'the',
#  'seventh',
#  'consecutive',
#  'year',
#  ',',
#  '#',
#  'SyracuseU',
#  'has',
#  'been',
#  'named',
#  'one',
#  'of',
#  'the',
#  'top',
#  'film',
#  'schools',
#  'in',
#  'the',
#  'country',
#  'by',
#  '@',
#  'THR',
#  '.',
#  '🎬…',
#  'https',
#  ':',
#  '//t.co/xE5btLAx9t',
#  'Happy',
#  '#',
#  'InternationalDogDay',
#  '!',
#  '🐾',
#  'Share',
#  'a',
#  'photo',
#  'of',
#  'your',
#  '#',
#  'SyracuseU',
#  'pup',
#  'with',
#  'us',
#  '!',
#  'https',
#  ':',
#  '//t.co/VSzNESBMOr',
#  'ICYMI',
#  ':',
#  'Watch',
#  'Chancellor',
#  'Syverud',
#  "'s",
#  'welcoming',
#  'message',
#  'to',
#  'new',
#  'students',
#  'and',
#  'their',
#  'families',
#  'during',
#  'the',
#  'fall',
#  '2019',
#  'New',
#  'Stu…',
#  'https',
#  ':',
#  '//t.co/E94ihCYahz',
#  'Welcome',
#  'back',
#  ',',
#  'students',
#  '!',
#  'Happy',
#  'first',
#  'day',
#  'of',
#  'classes',
#  '📚🍊',
#  'https',
#  ':',
#  '//t.co/GAcXP3TsLI',
#  'Orange',
#  'looks',
#  'good',
#  'on',
#  'you',
#  ',',
#  '#',
#  'Classof2023',
#  '🍊',
#  '#',
#  'SUWelcome',
#  'https',
#  ':',
#  '//t.co/5SqzSt7SMO',
#  '#',
#  'SyracuseU',
#  'has',
#  'never',
#  'been',
#  'bound',
#  'by',
#  'convention',
#  'or',
#  'the',
#  'status',
#  'quo',
#  '.',
#  'What',
#  'is',
#  'at',
#  'first',
#  'audacious',
#  'to',
#  'the',
#  'world',
#  'is',
#  'just',
#  'ri…',
#  'https',
#  ':',
#  '//t.co/OExMyNPDmv',
#  "''",
#  'Everyone',
#  'you',
#  'meet',
#  'here',
#  ',',
#  'including',
#  'those',
#  'who',
#  'look',
#  'or',
#  'speak',
#  'or',
#  'learn',
#  'differently',
#  'than',
#  'you',
#  ',',
#  'has',
#  'their',
#  'own',
#  'story',
#  '.',
#  'And…',
#  'https',
#  ':',
#  '//t.co/TTFCqyNlM3',
#  "''",
#  'This',
#  'is',
#  'your',
#  'University',
#  '’',
#  's',
#  '150th',
#  'birthday',
#  'year',
#  ',',
#  'and',
#  'we',
#  'will',
#  'be',
#  'marking',
#  'it',
#  'all',
#  'year',
#  'in',
#  'ways',
#  'appropriate',
#  'to',
#  'this',
#  'spra…',
#  'https',
#  ':',
#  '//t.co/lvFCvKD7Q2',
#  "''",
#  'Every',
#  'single',
#  'one',
#  'of',
#  'you',
#  'equally',
#  'belongs',
#  'here',
#  '.',
#  'As',
#  'far',
#  'as',
#  'all',
#  'of',
#  'us',
#  'are',
#  'concerned',
#  ',',
#  'you',
#  'are',
#  'each',
#  'now',
#  'forever',
#  'Orange',
#  '.',
#  '``',
#  '…',
#  'https',
#  ':',
#  '//t.co/J1oTi8Aniy',
#  'New',
#  'Student',
#  'Convocation',
#  'is',
#  'underway',
#  'in',
#  'the',
#  'Dome',
#  '!',
#  '🍊',
#  '#',
#  'SUWelcome',
#  'https',
#  ':',
#  '//t.co/gE0ft5luEG',
#  'RT',
#  '@',
#  'SyracuseULib',
#  ':',
#  'As',
#  'students',
#  'continue',
#  'to',
#  'arrive',
#  'this',
#  'week',
#  ',',
#  'we',
#  "'re",
#  'throwing',
#  'it',
#  'back',
#  'to',
#  '1971',
#  'for',
#  '#',
#  'SUWelcome',
#  '!',
#  'Different',
#  'fashion',
#  'choices',
#  ',',
#  'but',
#  't…']

# %%
cleantokens = [x for x in tokens if (len(x) > 1)]

cleantokens[1]
# Out:
# 'KatieNews4'

# %% [markdown]
# # Bi grams

# %%
from nltk import ngrams

# Arguments are (text,ngram number)

bigrams = ngrams(cleantokens,2)

for gram in bigrams:
    print(gram)
# Out:
# ('RT', 'KatieNews4')
# ('KatieNews4', 'Celebrating')
# ('Celebrating', 'CollegeColorsDay')
# ('CollegeColorsDay', 'in')
# ('in', 'the')
# ('the', 'news4buffalo')
# ('news4buffalo', 'newsroom')
# ('newsroom', 'zachsmalt')
# ('zachsmalt', 'and')
# ('and', 'are')
# ('are', 'just')
# ('just', 'couple')
# ('couple', 'of')
# ('of', 'SyracuseU')
# ('SyracuseU', 'NewhouseBDJ…')
# ('NewhouseBDJ…', 'RT')
# ('RT', 'Cuse')
# ('Cuse', 'Wake')
# ('Wake', 'up')
# ('up', 'It')
# ('It', "'s")
# ("'s", 'CollegeColorsDay')
# ('CollegeColorsDay', 'Wear')
# ('Wear', 'your')
# ('your', "'Cuse")
# ("'Cuse", 'gear')
# ('gear', 'and')
# ('and', 'rep')
# ('rep', 'the')
# ('the', 'Orange')
# ('Orange', 'https')
# ('https', '//t.co/u4Hpt74ZbQ')
# ('//t.co/u4Hpt74ZbQ', 'There')
# ('There', "'s")
# ("'s", 'nothing')
# ('nothing', 'quite')
# ('quite', 'like')
# ('like', 'the')
# ('the', 'excitement')
# ('excitement', 'of')
# ('of', 'new')
# ('new', 'semester')
# ('semester', 'at')
# ('at', 'SyracuseU')
# ('SyracuseU', 'Campus')
# ('Campus', 'is')
# ('is', 'buzzing')
# ('buzzing', 'https')
# ('https', '//t.co/OqEIntmXWy')
# ('//t.co/OqEIntmXWy', 'RT')
# ('RT', 'EngineeringSU')
# ('EngineeringSU', 'First')
# ('First', 'week')
# ('week', 'of')
# ('of', 'the')
# ('the', 'fall')
# ('fall', 'semester')
# ('semester', 'and')
# ('and', 'class')
# ('class', 'is')
# ('is', 'in')
# ('in', 'session')
# ('session', 'with')
# ('with', 'Professor')
# ('Professor', 'TheOttoOrange')
# ('TheOttoOrange', 'Skills')
# ('Skills', 'CoolAsIce')
# ('CoolAsIce', '🎵⬆️')
# ('🎵⬆️', 'Syracus…')
# ('Syracus…', 'TBT')
# ('TBT', 'Check')
# ('Check', 'out')
# ('out', 'some')
# ('some', 'of')
# ('of', 'our')
# ('our', 'favorite')
# ('favorite', 'photos')
# ('photos', 'from')
# ('from', 'SUWelcome')
# ('SUWelcome', 'in')
# ('in', 'our')
# ('our', 'Facebook')
# ('Facebook', 'photo')
# ('photo', 'album')
# ('album', 'https')
# ('https', '//t.co/HxXKg90viA')
# ('//t.co/HxXKg90viA', 'https')
# ('https', '//t.co/aeLTNqoAJ7')
# ('//t.co/aeLTNqoAJ7', 'RT')
# ('RT', 'michaelavarvis')
# ('michaelavarvis', 'The')
# ('The', 'fact')
# ('fact', 'that')
# ('that', 'get')
# ('get', 'to')
# ('to', 'pet')
# ('pet', 'dogs')
# ('dogs', 'days')
# ('days', 'week')
# ('week', 'in')
# ('in', 'the')
# ('the', 'Pet')
# ('Pet', 'Therapy')
# ('Therapy', 'room')
# ('room', 'is')
# ('is', 'amazing')
# ('amazing', 'Thank')
# ('Thank', 'you')
# ('you', 'SyracuseU')
# ('SyracuseU', 'https')
# ('https', '//t.co/tfJ…')
# ('//t.co/tfJ…', 'RT')
# ('RT', 'CuseFootball')
# ('CuseFootball', 'First')
# ('First', 'look')
# ('look', 'at')
# ('at', 'our')
# ('our', 'new')
# ('new', 'unis')
# ('unis', 'this')
# ('this', 'weekend')
# ('weekend', 'https')
# ('https', '//t.co/OknRfF4DHV')
# ('//t.co/OknRfF4DHV', 'The')
# ('The', 'Connective')
# ('Connective', 'Corridor')
# ('Corridor', 'path')
# ('path', 'that')
# ('that', 'links')
# ('links', 'the')
# ('the', 'campus')
# ('campus', 'community')
# ('community', 'with')
# ('with', 'downtown')
# ('downtown', 'Syracuse')
# ('Syracuse', 'gives')
# ('gives', 'students')
# ('students', 'easy')
# ('easy', 'access…')
# ('access…', 'https')
# ('https', '//t.co/O3bsILRaS3')
# ('//t.co/O3bsILRaS3', 'Rolling')
# ('Rolling', 'into')
# ('into', 'the')
# ('the', 'new')
# ('new', 'school')
# ('school', 'year')
# ('year', 'like..')
# ('like..', 'TheOttoOrange')
# ('TheOttoOrange', 'https')
# ('https', '//t.co/lqI1JOSjTG')
# ('//t.co/lqI1JOSjTG', 'For')
# ('For', 'the')
# ('the', 'seventh')
# ('seventh', 'consecutive')
# ('consecutive', 'year')
# ('year', 'SyracuseU')
# ('SyracuseU', 'has')
# ('has', 'been')
# ('been', 'named')
# ('named', 'one')
# ('one', 'of')
# ('of', 'the')
# ('the', 'top')
# ('top', 'film')
# ('film', 'schools')
# ('schools', 'in')
# ('in', 'the')
# ('the', 'country')
# ('country', 'by')
# ('by', 'THR')
# ('THR', '🎬…')
# ('🎬…', 'https')
# ('https', '//t.co/xE5btLAx9t')
# ('//t.co/xE5btLAx9t', 'Happy')
# ('Happy', 'InternationalDogDay')
# ('InternationalDogDay', 'Share')
# ('Share', 'photo')
# ('photo', 'of')
# ('of', 'your')
# ('your', 'SyracuseU')
# ('SyracuseU', 'pup')
# ('pup', 'with')
# ('with', 'us')
# ('us', 'https')
# ('https', '//t.co/VSzNESBMOr')
# ('//t.co/VSzNESBMOr', 'ICYMI')
# ('ICYMI', 'Watch')
# ('Watch', 'Chancellor')
# ('Chancellor', 'Syverud')
# ('Syverud', "'s")
# ("'s", 'welcoming')
# ('welcoming', 'message')
# ('message', 'to')
# ('to', 'new')
# ('new', 'students')
# ('students', 'and')
# ('and', 'their')
# ('their', 'families')
# ('families', 'during')
# ('during', 'the')
# ('the', 'fall')
# ('fall', '2019')
# ('2019', 'New')
# ('New', 'Stu…')
# ('Stu…', 'https')
# ('https', '//t.co/E94ihCYahz')
# ('//t.co/E94ihCYahz', 'Welcome')
# ('Welcome', 'back')
# ('back', 'students')
# ('students', 'Happy')
# ('Happy', 'first')
# ('first', 'day')
# ('day', 'of')
# ('of', 'classes')
# ('classes', '📚🍊')
# ('📚🍊', 'https')
# ('https', '//t.co/GAcXP3TsLI')
# ('//t.co/GAcXP3TsLI', 'Orange')
# ('Orange', 'looks')
# ('looks', 'good')
# ('good', 'on')
# ('on', 'you')
# ('you', 'Classof2023')
# ('Classof2023', 'SUWelcome')
# ('SUWelcome', 'https')
# ('https', '//t.co/5SqzSt7SMO')
# ('//t.co/5SqzSt7SMO', 'SyracuseU')
# ('SyracuseU', 'has')
# ('has', 'never')
# ('never', 'been')
# ('been', 'bound')
# ('bound', 'by')
# ('by', 'convention')
# ('convention', 'or')
# ('or', 'the')
# ('the', 'status')
# ('status', 'quo')
# ('quo', 'What')
# ('What', 'is')
# ('is', 'at')
# ('at', 'first')
# ('first', 'audacious')
# ('audacious', 'to')
# ('to', 'the')
# ('the', 'world')
# ('world', 'is')
# ('is', 'just')
# ('just', 'ri…')
# ('ri…', 'https')
# ('https', '//t.co/OExMyNPDmv')
# ('//t.co/OExMyNPDmv', "''")
# ("''", 'Everyone')
# ('Everyone', 'you')
# ('you', 'meet')
# ('meet', 'here')
# ('here', 'including')
# ('including', 'those')
# ('those', 'who')
# ('who', 'look')
# ('look', 'or')
# ('or', 'speak')
# ('speak', 'or')
# ('or', 'learn')
# ('learn', 'differently')
# ('differently', 'than')
# ('than', 'you')
# ('you', 'has')
# ('has', 'their')
# ('their', 'own')
# ('own', 'story')
# ('story', 'And…')
# ('And…', 'https')
# ('https', '//t.co/TTFCqyNlM3')
# ('//t.co/TTFCqyNlM3', "''")
# ("''", 'This')
# ('This', 'is')
# ('is', 'your')
# ('your', 'University')
# ('University', '150th')
# ('150th', 'birthday')
# ('birthday', 'year')
# ('year', 'and')
# ('and', 'we')
# ('we', 'will')
# ('will', 'be')
# ('be', 'marking')
# ('marking', 'it')
# ('it', 'all')
# ('all', 'year')
# ('year', 'in')
# ('in', 'ways')
# ('ways', 'appropriate')
# ('appropriate', 'to')
# ('to', 'this')
# ('this', 'spra…')
# ('spra…', 'https')
# ('https', '//t.co/lvFCvKD7Q2')
# ('//t.co/lvFCvKD7Q2', "''")
# ("''", 'Every')
# ('Every', 'single')
# ('single', 'one')
# ('one', 'of')
# ('of', 'you')
# ('you', 'equally')
# ('equally', 'belongs')
# ('belongs', 'here')
# ('here', 'As')
# ('As', 'far')
# ('far', 'as')
# ('as', 'all')
# ('all', 'of')
# ('of', 'us')
# ('us', 'are')
# ('are', 'concerned')
# ('concerned', 'you')
# ('you', 'are')
# ('are', 'each')
# ('each', 'now')
# ('now', 'forever')
# ('forever', 'Orange')
# ('Orange', '``')
# ('``', 'https')
# ('https', '//t.co/J1oTi8Aniy')
# ('//t.co/J1oTi8Aniy', 'New')
# ('New', 'Student')
# ('Student', 'Convocation')
# ('Convocation', 'is')
# ('is', 'underway')
# ('underway', 'in')
# ('in', 'the')
# ('the', 'Dome')
# ('Dome', 'SUWelcome')
# ('SUWelcome', 'https')
# ('https', '//t.co/gE0ft5luEG')
# ('//t.co/gE0ft5luEG', 'RT')
# ('RT', 'SyracuseULib')
# ('SyracuseULib', 'As')
# ('As', 'students')
# ('students', 'continue')
# ('continue', 'to')
# ('to', 'arrive')
# ('arrive', 'this')
# ('this', 'week')
# ('week', 'we')
# ('we', "'re")
# ("'re", 'throwing')
# ('throwing', 'it')
# ('it', 'back')
# ('back', 'to')
# ('to', '1971')
# ('1971', 'for')
# ('for', 'SUWelcome')
# ('SUWelcome', 'Different')
# ('Different', 'fashion')
# ('fashion', 'choices')
# ('choices', 'but')
# ('but', 't…')

# %% [markdown]
# # Trigrams

# %%
trigrams = ngrams(cleantokens,3)

for gram in trigrams:
    print(gram)
# Out:
# ('RT', 'KatieNews4', 'Celebrating')
# ('KatieNews4', 'Celebrating', 'CollegeColorsDay')
# ('Celebrating', 'CollegeColorsDay', 'in')
# ('CollegeColorsDay', 'in', 'the')
# ('in', 'the', 'news4buffalo')
# ('the', 'news4buffalo', 'newsroom')
# ('news4buffalo', 'newsroom', 'zachsmalt')
# ('newsroom', 'zachsmalt', 'and')
# ('zachsmalt', 'and', 'are')
# ('and', 'are', 'just')
# ('are', 'just', 'couple')
# ('just', 'couple', 'of')
# ('couple', 'of', 'SyracuseU')
# ('of', 'SyracuseU', 'NewhouseBDJ…')
# ('SyracuseU', 'NewhouseBDJ…', 'RT')
# ('NewhouseBDJ…', 'RT', 'Cuse')
# ('RT', 'Cuse', 'Wake')
# ('Cuse', 'Wake', 'up')
# ('Wake', 'up', 'It')
# ('up', 'It', "'s")
# ('It', "'s", 'CollegeColorsDay')
# ("'s", 'CollegeColorsDay', 'Wear')
# ('CollegeColorsDay', 'Wear', 'your')
# ('Wear', 'your', "'Cuse")
# ('your', "'Cuse", 'gear')
# ("'Cuse", 'gear', 'and')
# ('gear', 'and', 'rep')
# ('and', 'rep', 'the')
# ('rep', 'the', 'Orange')
# ('the', 'Orange', 'https')
# ('Orange', 'https', '//t.co/u4Hpt74ZbQ')
# ('https', '//t.co/u4Hpt74ZbQ', 'There')
# ('//t.co/u4Hpt74ZbQ', 'There', "'s")
# ('There', "'s", 'nothing')
# ("'s", 'nothing', 'quite')
# ('nothing', 'quite', 'like')
# ('quite', 'like', 'the')
# ('like', 'the', 'excitement')
# ('the', 'excitement', 'of')
# ('excitement', 'of', 'new')
# ('of', 'new', 'semester')
# ('new', 'semester', 'at')
# ('semester', 'at', 'SyracuseU')
# ('at', 'SyracuseU', 'Campus')
# ('SyracuseU', 'Campus', 'is')
# ('Campus', 'is', 'buzzing')
# ('is', 'buzzing', 'https')
# ('buzzing', 'https', '//t.co/OqEIntmXWy')
# ('https', '//t.co/OqEIntmXWy', 'RT')
# ('//t.co/OqEIntmXWy', 'RT', 'EngineeringSU')
# ('RT', 'EngineeringSU', 'First')
# ('EngineeringSU', 'First', 'week')
# ('First', 'week', 'of')
# ('week', 'of', 'the')
# ('of', 'the', 'fall')
# ('the', 'fall', 'semester')
# ('fall', 'semester', 'and')
# ('semester', 'and', 'class')
# ('and', 'class', 'is')
# ('class', 'is', 'in')
# ('is', 'in', 'session')
# ('in', 'session', 'with')
# ('session', 'with', 'Professor')
# ('with', 'Professor', 'TheOttoOrange')
# ('Professor', 'TheOttoOrange', 'Skills')
# ('TheOttoOrange', 'Skills', 'CoolAsIce')
# ('Skills', 'CoolAsIce', '🎵⬆️')
# ('CoolAsIce', '🎵⬆️', 'Syracus…')
# ('🎵⬆️', 'Syracus…', 'TBT')
# ('Syracus…', 'TBT', 'Check')
# ('TBT', 'Check', 'out')
# ('Check', 'out', 'some')
# ('out', 'some', 'of')
# ('some', 'of', 'our')
# ('of', 'our', 'favorite')
# ('our', 'favorite', 'photos')
# ('favorite', 'photos', 'from')
# ('photos', 'from', 'SUWelcome')
# ('from', 'SUWelcome', 'in')
# ('SUWelcome', 'in', 'our')
# ('in', 'our', 'Facebook')
# ('our', 'Facebook', 'photo')
# ('Facebook', 'photo', 'album')
# ('photo', 'album', 'https')
# ('album', 'https', '//t.co/HxXKg90viA')
# ('https', '//t.co/HxXKg90viA', 'https')
# ('//t.co/HxXKg90viA', 'https', '//t.co/aeLTNqoAJ7')
# ('https', '//t.co/aeLTNqoAJ7', 'RT')
# ('//t.co/aeLTNqoAJ7', 'RT', 'michaelavarvis')
# ('RT', 'michaelavarvis', 'The')
# ('michaelavarvis', 'The', 'fact')
# ('The', 'fact', 'that')
# ('fact', 'that', 'get')
# ('that', 'get', 'to')
# ('get', 'to', 'pet')
# ('to', 'pet', 'dogs')
# ('pet', 'dogs', 'days')
# ('dogs', 'days', 'week')
# ('days', 'week', 'in')
# ('week', 'in', 'the')
# ('in', 'the', 'Pet')
# ('the', 'Pet', 'Therapy')
# ('Pet', 'Therapy', 'room')
# ('Therapy', 'room', 'is')
# ('room', 'is', 'amazing')
# ('is', 'amazing', 'Thank')
# ('amazing', 'Thank', 'you')
# ('Thank', 'you', 'SyracuseU')
# ('you', 'SyracuseU', 'https')
# ('SyracuseU', 'https', '//t.co/tfJ…')
# ('https', '//t.co/tfJ…', 'RT')
# ('//t.co/tfJ…', 'RT', 'CuseFootball')
# ('RT', 'CuseFootball', 'First')
# ('CuseFootball', 'First', 'look')
# ('First', 'look', 'at')
# ('look', 'at', 'our')
# ('at', 'our', 'new')
# ('our', 'new', 'unis')
# ('new', 'unis', 'this')
# ('unis', 'this', 'weekend')
# ('this', 'weekend', 'https')
# ('weekend', 'https', '//t.co/OknRfF4DHV')
# ('https', '//t.co/OknRfF4DHV', 'The')
# ('//t.co/OknRfF4DHV', 'The', 'Connective')
# ('The', 'Connective', 'Corridor')
# ('Connective', 'Corridor', 'path')
# ('Corridor', 'path', 'that')
# ('path', 'that', 'links')
# ('that', 'links', 'the')
# ('links', 'the', 'campus')
# ('the', 'campus', 'community')
# ('campus', 'community', 'with')
# ('community', 'with', 'downtown')
# ('with', 'downtown', 'Syracuse')
# ('downtown', 'Syracuse', 'gives')
# ('Syracuse', 'gives', 'students')
# ('gives', 'students', 'easy')
# ('students', 'easy', 'access…')
# ('easy', 'access…', 'https')
# ('access…', 'https', '//t.co/O3bsILRaS3')
# ('https', '//t.co/O3bsILRaS3', 'Rolling')
# ('//t.co/O3bsILRaS3', 'Rolling', 'into')
# ('Rolling', 'into', 'the')
# ('into', 'the', 'new')
# ('the', 'new', 'school')
# ('new', 'school', 'year')
# ('school', 'year', 'like..')
# ('year', 'like..', 'TheOttoOrange')
# ('like..', 'TheOttoOrange', 'https')
# ('TheOttoOrange', 'https', '//t.co/lqI1JOSjTG')
# ('https', '//t.co/lqI1JOSjTG', 'For')
# ('//t.co/lqI1JOSjTG', 'For', 'the')
# ('For', 'the', 'seventh')
# ('the', 'seventh', 'consecutive')
# ('seventh', 'consecutive', 'year')
# ('consecutive', 'year', 'SyracuseU')
# ('year', 'SyracuseU', 'has')
# ('SyracuseU', 'has', 'been')
# ('has', 'been', 'named')
# ('been', 'named', 'one')
# ('named', 'one', 'of')
# ('one', 'of', 'the')
# ('of', 'the', 'top')
# ('the', 'top', 'film')
# ('top', 'film', 'schools')
# ('film', 'schools', 'in')
# ('schools', 'in', 'the')
# ('in', 'the', 'country')
# ('the', 'country', 'by')
# ('country', 'by', 'THR')
# ('by', 'THR', '🎬…')
# ('THR', '🎬…', 'https')
# ('🎬…', 'https', '//t.co/xE5btLAx9t')
# ('https', '//t.co/xE5btLAx9t', 'Happy')
# ('//t.co/xE5btLAx9t', 'Happy', 'InternationalDogDay')
# ('Happy', 'InternationalDogDay', 'Share')
# ('InternationalDogDay', 'Share', 'photo')
# ('Share', 'photo', 'of')
# ('photo', 'of', 'your')
# ('of', 'your', 'SyracuseU')
# ('your', 'SyracuseU', 'pup')
# ('SyracuseU', 'pup', 'with')
# ('pup', 'with', 'us')
# ('with', 'us', 'https')
# ('us', 'https', '//t.co/VSzNESBMOr')
# ('https', '//t.co/VSzNESBMOr', 'ICYMI')
# ('//t.co/VSzNESBMOr', 'ICYMI', 'Watch')
# ('ICYMI', 'Watch', 'Chancellor')
# ('Watch', 'Chancellor', 'Syverud')
# ('Chancellor', 'Syverud', "'s")
# ('Syverud', "'s", 'welcoming')
# ("'s", 'welcoming', 'message')
# ('welcoming', 'message', 'to')
# ('message', 'to', 'new')
# ('to', 'new', 'students')
# ('new', 'students', 'and')
# ('students', 'and', 'their')
# ('and', 'their', 'families')
# ('their', 'families', 'during')
# ('families', 'during', 'the')
# ('during', 'the', 'fall')
# ('the', 'fall', '2019')
# ('fall', '2019', 'New')
# ('2019', 'New', 'Stu…')
# ('New', 'Stu…', 'https')
# ('Stu…', 'https', '//t.co/E94ihCYahz')
# ('https', '//t.co/E94ihCYahz', 'Welcome')
# ('//t.co/E94ihCYahz', 'Welcome', 'back')
# ('Welcome', 'back', 'students')
# ('back', 'students', 'Happy')
# ('students', 'Happy', 'first')
# ('Happy', 'first', 'day')
# ('first', 'day', 'of')
# ('day', 'of', 'classes')
# ('of', 'classes', '📚🍊')
# ('classes', '📚🍊', 'https')
# ('📚🍊', 'https', '//t.co/GAcXP3TsLI')
# ('https', '//t.co/GAcXP3TsLI', 'Orange')
# ('//t.co/GAcXP3TsLI', 'Orange', 'looks')
# ('Orange', 'looks', 'good')
# ('looks', 'good', 'on')
# ('good', 'on', 'you')
# ('on', 'you', 'Classof2023')
# ('you', 'Classof2023', 'SUWelcome')
# ('Classof2023', 'SUWelcome', 'https')
# ('SUWelcome', 'https', '//t.co/5SqzSt7SMO')
# ('https', '//t.co/5SqzSt7SMO', 'SyracuseU')
# ('//t.co/5SqzSt7SMO', 'SyracuseU', 'has')
# ('SyracuseU', 'has', 'never')
# ('has', 'never', 'been')
# ('never', 'been', 'bound')
# ('been', 'bound', 'by')
# ('bound', 'by', 'convention')
# ('by', 'convention', 'or')
# ('convention', 'or', 'the')
# ('or', 'the', 'status')
# ('the', 'status', 'quo')
# ('status', 'quo', 'What')
# ('quo', 'What', 'is')
# ('What', 'is', 'at')
# ('is', 'at', 'first')
# ('at', 'first', 'audacious')
# ('first', 'audacious', 'to')
# ('audacious', 'to', 'the')
# ('to', 'the', 'world')
# ('the', 'world', 'is')
# ('world', 'is', 'just')
# ('is', 'just', 'ri…')
# ('just', 'ri…', 'https')
# ('ri…', 'https', '//t.co/OExMyNPDmv')
# ('https', '//t.co/OExMyNPDmv', "''")
# ('//t.co/OExMyNPDmv', "''", 'Everyone')
# ("''", 'Everyone', 'you')
# ('Everyone', 'you', 'meet')
# ('you', 'meet', 'here')
# ('meet', 'here', 'including')
# ('here', 'including', 'those')
# ('including', 'those', 'who')
# ('those', 'who', 'look')
# ('who', 'look', 'or')
# ('look', 'or', 'speak')
# ('or', 'speak', 'or')
# ('speak', 'or', 'learn')
# ('or', 'learn', 'differently')
# ('learn', 'differently', 'than')
# ('differently', 'than', 'you')
# ('than', 'you', 'has')
# ('you', 'has', 'their')
# ('has', 'their', 'own')
# ('their', 'own', 'story')
# ('own', 'story', 'And…')
# ('story', 'And…', 'https')
# ('And…', 'https', '//t.co/TTFCqyNlM3')
# ('https', '//t.co/TTFCqyNlM3', "''")
# ('//t.co/TTFCqyNlM3', "''", 'This')
# ("''", 'This', 'is')
# ('This', 'is', 'your')
# ('is', 'your', 'University')
# ('your', 'University', '150th')
# ('University', '150th', 'birthday')
# ('150th', 'birthday', 'year')
# ('birthday', 'year', 'and')
# ('year', 'and', 'we')
# ('and', 'we', 'will')
# ('we', 'will', 'be')
# ('will', 'be', 'marking')
# ('be', 'marking', 'it')
# ('marking', 'it', 'all')
# ('it', 'all', 'year')
# ('all', 'year', 'in')
# ('year', 'in', 'ways')
# ('in', 'ways', 'appropriate')
# ('ways', 'appropriate', 'to')
# ('appropriate', 'to', 'this')
# ('to', 'this', 'spra…')
# ('this', 'spra…', 'https')
# ('spra…', 'https', '//t.co/lvFCvKD7Q2')
# ('https', '//t.co/lvFCvKD7Q2', "''")
# ('//t.co/lvFCvKD7Q2', "''", 'Every')
# ("''", 'Every', 'single')
# ('Every', 'single', 'one')
# ('single', 'one', 'of')
# ('one', 'of', 'you')
# ('of', 'you', 'equally')
# ('you', 'equally', 'belongs')
# ('equally', 'belongs', 'here')
# ('belongs', 'here', 'As')
# ('here', 'As', 'far')
# ('As', 'far', 'as')
# ('far', 'as', 'all')
# ('as', 'all', 'of')
# ('all', 'of', 'us')
# ('of', 'us', 'are')
# ('us', 'are', 'concerned')
# ('are', 'concerned', 'you')
# ('concerned', 'you', 'are')
# ('you', 'are', 'each')
# ('are', 'each', 'now')
# ('each', 'now', 'forever')
# ('now', 'forever', 'Orange')
# ('forever', 'Orange', '``')
# ('Orange', '``', 'https')
# ('``', 'https', '//t.co/J1oTi8Aniy')
# ('https', '//t.co/J1oTi8Aniy', 'New')
# ('//t.co/J1oTi8Aniy', 'New', 'Student')
# ('New', 'Student', 'Convocation')
# ('Student', 'Convocation', 'is')
# ('Convocation', 'is', 'underway')
# ('is', 'underway', 'in')
# ('underway', 'in', 'the')
# ('in', 'the', 'Dome')
# ('the', 'Dome', 'SUWelcome')
# ('Dome', 'SUWelcome', 'https')
# ('SUWelcome', 'https', '//t.co/gE0ft5luEG')
# ('https', '//t.co/gE0ft5luEG', 'RT')
# ('//t.co/gE0ft5luEG', 'RT', 'SyracuseULib')
# ('RT', 'SyracuseULib', 'As')
# ('SyracuseULib', 'As', 'students')
# ('As', 'students', 'continue')
# ('students', 'continue', 'to')
# ('continue', 'to', 'arrive')
# ('to', 'arrive', 'this')
# ('arrive', 'this', 'week')
# ('this', 'week', 'we')
# ('week', 'we', "'re")
# ('we', "'re", 'throwing')
# ("'re", 'throwing', 'it')
# ('throwing', 'it', 'back')
# ('it', 'back', 'to')
# ('back', 'to', '1971')
# ('to', '1971', 'for')
# ('1971', 'for', 'SUWelcome')
# ('for', 'SUWelcome', 'Different')
# ('SUWelcome', 'Different', 'fashion')
# ('Different', 'fashion', 'choices')
# ('fashion', 'choices', 'but')
# ('choices', 'but', 't…')

# %%
texts = nltk.Text(cleantokens)
for text in texts:
    print(text)
# Out:
# RT
# @
# KatieNews4
# :
# Celebrating
# #
# CollegeColorsDay
# in
# the
# @
# news4buffalo
# newsroom
# .
# @
# zachsmalt
# and
# I
# are
# just
# a
# couple
# of
# @
# SyracuseU
# @
# NewhouseBDJ…
# RT
# @
# Cuse
# :
# Wake
# up
# !
# It
# 's
# #
# CollegeColorsDay
# !
# Wear
# your
# 'Cuse
# gear
# and
# rep
# the
# Orange
# !
# 🍊
# https
# :
# //t.co/u4Hpt74ZbQ
# There
# 's
# nothing
# quite
# like
# the
# excitement
# of
# a
# new
# semester
# at
# #
# SyracuseU
# 🍊
# Campus
# is
# buzzing
# !
# https
# :
# //t.co/OqEIntmXWy
# RT
# @
# EngineeringSU
# :
# First
# week
# of
# the
# fall
# semester
# and
# class
# is
# in
# session
# with
# Professor
# @
# TheOttoOrange
# !
# 🍊
# #
# Skills
# #
# CoolAsIce
# 🎵⬆️
# @
# Syracus…
# #
# TBT
# Check
# out
# some
# of
# our
# favorite
# photos
# from
# #
# SUWelcome
# in
# our
# Facebook
# photo
# album
# :
# https
# :
# //t.co/HxXKg90viA
# https
# :
# //t.co/aeLTNqoAJ7
# RT
# @
# michaelavarvis
# :
# The
# fact
# that
# I
# get
# to
# pet
# dogs
# 3
# days
# a
# week
# in
# the
# Pet
# Therapy
# room
# is
# amazing
# .
# Thank
# you
# @
# SyracuseU
# https
# :
# //t.co/tfJ…
# RT
# @
# CuseFootball
# :
# 👀
# First
# look
# at
# our
# new
# unis
# this
# weekend
# .
# https
# :
# //t.co/OknRfF4DHV
# The
# Connective
# Corridor
# ,
# a
# path
# that
# links
# the
# campus
# community
# with
# downtown
# Syracuse
# ,
# gives
# students
# easy
# access…
# https
# :
# //t.co/O3bsILRaS3
# Rolling
# into
# the
# new
# school
# year
# like..
# @
# TheOttoOrange
# https
# :
# //t.co/lqI1JOSjTG
# For
# the
# seventh
# consecutive
# year
# ,
# #
# SyracuseU
# has
# been
# named
# one
# of
# the
# top
# film
# schools
# in
# the
# country
# by
# @
# THR
# .
# 🎬…
# https
# :
# //t.co/xE5btLAx9t
# Happy
# #
# InternationalDogDay
# !
# 🐾
# Share
# a
# photo
# of
# your
# #
# SyracuseU
# pup
# with
# us
# !
# https
# :
# //t.co/VSzNESBMOr
# ICYMI
# :
# Watch
# Chancellor
# Syverud
# 's
# welcoming
# message
# to
# new
# students
# and
# their
# families
# during
# the
# fall
# 2019
# New
# Stu…
# https
# :
# //t.co/E94ihCYahz
# Welcome
# back
# ,
# students
# !
# Happy
# first
# day
# of
# classes
# 📚🍊
# https
# :
# //t.co/GAcXP3TsLI
# Orange
# looks
# good
# on
# you
# ,
# #
# Classof2023
# 🍊
# #
# SUWelcome
# https
# :
# //t.co/5SqzSt7SMO
# #
# SyracuseU
# has
# never
# been
# bound
# by
# convention
# or
# the
# status
# quo
# .
# What
# is
# at
# first
# audacious
# to
# the
# world
# is
# just
# ri…
# https
# :
# //t.co/OExMyNPDmv
# ''
# Everyone
# you
# meet
# here
# ,
# including
# those
# who
# look
# or
# speak
# or
# learn
# differently
# than
# you
# ,
# has
# their
# own
# story
# .
# And…
# https
# :
# //t.co/TTFCqyNlM3
# ''
# This
# is
# your
# University
# ’
# s
# 150th
# birthday
# year
# ,
# and
# we
# will
# be
# marking
# it
# all
# year
# in
# ways
# appropriate
# to
# this
# spra…
# https
# :
# //t.co/lvFCvKD7Q2
# ''
# Every
# single
# one
# of
# you
# equally
# belongs
# here
# .
# As
# far
# as
# all
# of
# us
# are
# concerned
# ,
# you
# are
# each
# now
# forever
# Orange
# .
# ``
# …
# https
# :
# //t.co/J1oTi8Aniy
# New
# Student
# Convocation
# is
# underway
# in
# the
# Dome
# !
# 🍊
# #
# SUWelcome
# https
# :
# //t.co/gE0ft5luEG
# RT
# @
# SyracuseULib
# :
# As
# students
# continue
# to
# arrive
# this
# week
# ,
# we
# 're
# throwing
# it
# back
# to
# 1971
# for
# #
# SUWelcome
# !
# Different
# fashion
# choices
# ,
# but
# t…

# %% [markdown]
# # Common Tokens

# %%
# In[13]:


wordsCP = nltk.FreqDist(cleantokens)


# In[14]:


wordsCP.most_common(30)
# Out:
# [('https', 18),
#  ('the', 14),
#  ('of', 9),
#  ('in', 7),
#  ('is', 7),
#  ('RT', 6),
#  ('SyracuseU', 6),
#  ('to', 6),
#  ('you', 6),
#  ('and', 5),
#  ('new', 4),
#  ('SUWelcome', 4),
#  ('students', 4),
#  ('year', 4),
#  ('are', 3),
#  ("'s", 3),
#  ('your', 3),
#  ('Orange', 3),
#  ('at', 3),
#  ('week', 3),
#  ('with', 3),
#  ('our', 3),
#  ('this', 3),
#  ('has', 3),
#  ('or', 3),
#  ("''", 3),
#  ('CollegeColorsDay', 2),
#  ('just', 2),
#  ('semester', 2),
#  ('First', 2)]

# %%
# In[15]:


all_tokens = [tokens.lower() for tokens in wordsCP for tokens in nltk.word_tokenize(tokens)]


# In[16]:


all_tokens[:30]


# In[17]:


#nltk_stopwords = nltk.corpus.stopwords.words('english')
#len(nltk_stopwords)
# Out:
# ['rt',
#  'katienews4',
#  'celebrating',
#  'collegecolorsday',
#  'in',
#  'the',
#  'news4buffalo',
#  'newsroom',
#  'zachsmalt',
#  'and',
#  'are',
#  'just',
#  'couple',
#  'of',
#  'syracuseu',
#  'newhousebdj…',
#  'cuse',
#  'wake',
#  'up',
#  'it',
#  "'s",
#  'wear',
#  'your',
#  "'cuse",
#  'gear',
#  'rep',
#  'orange',
#  'https',
#  '//t.co/u4hpt74zbq',
#  'there']

# %%
import re
def alpha_filter(w):
    pattern = re.compile('^[^a-z]+$')
    if (pattern.match(w)):
        return True
    else:
        return False


# In[19]:


token_list = [token for token in all_tokens if not alpha_filter(token)]


# In[20]:


token_list[:30]
# Out:
# ['rt',
#  'katienews4',
#  'celebrating',
#  'collegecolorsday',
#  'in',
#  'the',
#  'news4buffalo',
#  'newsroom',
#  'zachsmalt',
#  'and',
#  'are',
#  'just',
#  'couple',
#  'of',
#  'syracuseu',
#  'newhousebdj…',
#  'cuse',
#  'wake',
#  'up',
#  'it',
#  "'s",
#  'wear',
#  'your',
#  "'cuse",
#  'gear',
#  'rep',
#  'orange',
#  'https',
#  '//t.co/u4hpt74zbq',
#  'there']

# %%
# In[21]:


wordsCP = nltk.FreqDist(token_list)


# In[22]:


top_words = wordsCP.most_common(30)


# In[23]:


for word, freq in top_words:
    print(word, freq)


# In[ ]:
# Out:
# the 2
# it 2
# new 2
# campus 2
# first 2
# pet 2
# this 2
# for 2
# as 2
# rt 1
# katienews4 1
# celebrating 1
# collegecolorsday 1
# in 1
# news4buffalo 1
# newsroom 1
# zachsmalt 1
# and 1
# are 1
# just 1
# couple 1
# of 1
# syracuseu 1
# newhousebdj… 1
# cuse 1
# wake 1
# up 1
# 's 1
# wear 1
# your 1

# %% [markdown]
# #  With MongoDB (courtesty of Andew Leavitt)

# %%
"""
Created on Thu Aug 29 17:46:09 2019
@author: Thoraxe
"""
#9.2 exercise
#connect to mongodb
import pymongo
import nltk
from nltk import punkt
from nltk import word_tokenize
import re
nltk.download('punkt')
nltk.download('stopwords')
client = pymongo.MongoClient()
#check names
client.database_names()
#setting database to the bball db for this exercise
db=client.bball
#checking bball collection names
db.collection_names()
#setting collection
coll = db.bbcoll
#setting cursor
docs=coll.find()
#turning cursor into a list
doclist= [x for x in docs]
#changing doclist to a string so I can use word_tokenize
docstr=(str(doclist).strip('[]')) # JASON's NOTE: this is not a good idea!
# Out:
# [nltk_data] Downloading package punkt to /Users/jason/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/jason/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /Users/jason/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
#   app.launch_new_instance()
# /Users/jason/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.

# %% [markdown]
# ### Instead you want to only extract the text

# %%
bball_tweets = [tweet['text'] for tweet in doclist]

bball_tweets[0:10]
# Out:
# ['RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…',
#  'RT @WhistleSports: When you perfectly time the #UNC buzzer beater 😱🏀 #MarchMadness\n\n(via:@SamuelGrubbs1 ) https://t.co/Ol2ibpZjB4',
#  'RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…',
#  'RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC',
#  "RT @mycarolinastdnt: RT if you'll be cheering on @GamecockWBB and @dawnstaley tonight. Let's Go Gamecocks! #MarchMadness",
#  'RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…',
#  "RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…",
#  '"It’s OK to believe in the hot hand." https://t.co/yJOqhlRz8L h/t @ConversationUS #MarchMadness #NCAA',
#  "It's gonna be a Civil War for the finals! #MarchMadness",
#  'Beach ready? #trend #vip #marketing #marchmadness #UnnecessaryConfessions #younotfromhouston… https://t.co/AtoeIuQuXk']

# %%
tokens = []
for tweet in bball_tweets:
    tweettoken = nltk.word_tokenize(tweet)
    tokens.append(tweettoken)
    
tokens[0]
# Out:
# ['RT',
#  '@',
#  'HowardWKYT',
#  ':',
#  'The',
#  'final',
#  'seconds',
#  'of',
#  'the',
#  'Kentucky-North',
#  'Carolina',
#  'game',
#  'was',
#  'an',
#  'emotional',
#  'roller',
#  'coaster',
#  'for',
#  'Big',
#  'Blue',
#  'fans',
#  '.',
#  '#',
#  'marchmadness',
#  '#',
#  'WKY…']

# %% [markdown]
# # Can we try to analyze the sentiment in tweets?

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sentences = ['This was a really good book.', 'This movie was so bad.',"I like to hate Michael Bay films, but I couldn't fault this one"]
sid = SentimentIntensityAnalyzer()
for sentence in sentences:
	print(sentence)
	ss = sid.polarity_scores(sentence)
	for k in sorted(ss):
		print('{0}: {1}, '.format(k, ss[k]), end='')
	print()
# Out:
# This was a really good book.
# compound: 0.4927, neg: 0.0, neu: 0.556, pos: 0.444,
# This movie was so bad.
# compound: -0.6696, neg: 0.529, neu: 0.471, pos: 0.0,
# I like to hate Michael Bay films, but I couldn't fault this one
# compound: 0.3153, neg: 0.157, neu: 0.534, pos: 0.309,

# %%
for tweet in bball_tweets:
	print(tweet)
	ss = sid.polarity_scores(tweet)
	for k in sorted(ss):
		print('{0}: {1}, '.format(k, ss[k]), end='')
	print()
# Out:
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @WhistleSports: When you perfectly time the #UNC buzzer beater 😱🏀 #MarchMadness
#
# (via:@SamuelGrubbs1 ) https://t.co/Ol2ibpZjB4
# compound: 0.6369, neg: 0.0, neu: 0.756, pos: 0.244,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @mycarolinastdnt: RT if you'll be cheering on @GamecockWBB and @dawnstaley tonight. Let's Go Gamecocks! #MarchMadness
# compound: 0.5562, neg: 0.0, neu: 0.807, pos: 0.193,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# "It’s OK to believe in the hot hand." https://t.co/yJOqhlRz8L h/t @ConversationUS #MarchMadness #NCAA
# compound: 0.4466, neg: 0.0, neu: 0.804, pos: 0.196,
# It's gonna be a Civil War for the finals! #MarchMadness
# compound: -0.636, neg: 0.344, neu: 0.656, pos: 0.0,
# Beach ready? #trend #vip #marketing #marchmadness #UnnecessaryConfessions #younotfromhouston… https://t.co/AtoeIuQuXk
# compound: 0.3612, neg: 0.0, neu: 0.762, pos: 0.238,
# Industry Monday! @ShakerChicago #mondaymotivation #internationalwhiskyday #MarchMadness #spanishpaelladay… https://t.co/rTw25qvjRS
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @TheEllenShow: Everyone’s mad for #MarchMadness, especially my montage editor. https://t.co/1wpXbeONPL
# compound: -0.4939, neg: 0.242, neu: 0.758, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @CoachSueFSU: Guess what? It's GAMEDAY! #fsuwbb #marchmadness #ncaaW #TogetherWeRise https://t.co/24yLBqgHGV
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @LGUS: Keep 'em on their heels @UNC_Basketball, it's rally time! #MarchMadness #LGSideKick https://t.co/TJddu2r8tO
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# i won by default 😆 but i'm so proud of @hhn4334  and aiden for our first #marchmadness together https://t.co/XPO3jztjdG
# compound: 0.8333, neg: 0.0, neu: 0.657, pos: 0.343,
# RT @POWERADE: Who are you when nobody’s watching? @Dame_Lillard is #justakidfrom Oakland. #PowerThrough #MarchMadness https://t.co/3LEAFGD6…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @TyKellyandChuck: A #FinalFour Song for @dariusrucker! Today's #10MinuteTune from @SBSwags..  #MarchMadness #SouthCarolina https://t.co/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# #UnnecessaryConfessions #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words Raiders true… https://t.co/kMxHA9JGzq
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Bury the bastards. #MSNBC #CNN #CBS #NBC #PBS #WHYN #WBZ #Boston #BostonMarathon #MarchMadness American taxpayers p… https://t.co/HU2IXv6GQa
# compound: -0.6124, neg: 0.2, neu: 0.8, pos: 0.0,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @mass_mont: Bury the bastards. #MSNBC #CNN #CBS #NBC #PBS #WHYN #WBZ #Boston #BostonMarathon #MGH #MarchMadness   #Movies       Excellen…
# compound: -0.6124, neg: 0.19, neu: 0.81, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @WhistleSports: When you perfectly time the #UNC buzzer beater 😱🏀 #MarchMadness
#
# (via:@SamuelGrubbs1 ) https://t.co/Ol2ibpZjB4
# compound: 0.6369, neg: 0.0, neu: 0.756, pos: 0.244,
# RT @USCstudentTIX: Student ticket information for #FinalFour @GamecockMBB will be sent out early this week #marchmadness
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @WFMY: .@UNC_Basketball has played in 19 #FinalFour more than any other school #Marchmadness See them Saturday night on WFMY News 2 http…
# compound: 0.34, neg: 0.0, neu: 0.897, pos: 0.103,
# RT @FloridaGators: Congratulations to @GamecockMBB - go win the rest! #SEC #MarchMadness
# compound: 0.8398, neg: 0.0, neu: 0.53, pos: 0.47,
# RT @espn975: Thank you so much @wingstop for bringing amazing wings to the studio today!! @Degenerates975 is very happy!! #MarchMadness #Fi…
# compound: 0.9093, neg: 0.0, neu: 0.611, pos: 0.389,
# RT @Im_Cole7: "Who's going to make the game winner?" #UNCvsUK #MarchMadness https://t.co/u3MxJ0RVeG
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BovadaLV: RT our special #MarchMadness #SWEET16 #PeoplesParlay before tomorrow night at 7PM ET and if it hits, we'll split the winnings…
# compound: 0.4019, neg: 0.0, neu: 0.886, pos: 0.114,
# RT @WhistleSports: When you perfectly time the #UNC buzzer beater 😱🏀 #MarchMadness
#
# (via:@SamuelGrubbs1 ) https://t.co/Ol2ibpZjB4
# compound: 0.6369, neg: 0.0, neu: 0.756, pos: 0.244,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Got my GORGEOUS (and a bit disturbing!) deluxe ed. of LILY today! Get yours on super sale in March:… https://t.co/gJ0dGHgJZR
# compound: 0.8811, neg: 0.0, neu: 0.648, pos: 0.352,
# How the Raiders' move to Las Vegas might boost UNLV football https://t.co/aILrVYfkgW #marchmadness
# compound: 0.4019, neg: 0.0, neu: 0.816, pos: 0.184,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# All new listings in our #marchmadness #springsale #booksale #onlinesale
#
# https://t.co/b66jCpT5J4
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Bury the bastards. #MSNBC #CNN #CBS #NBC #PBS #WHYN #WBZ #Boston #BostonMarathon #MGH #MarchMadness   #Movies… https://t.co/WxE9p155Ca
# compound: -0.6124, neg: 0.211, neu: 0.789, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @Animal_Bracket: Which would YOU rather be? #Sweet16 #MarchMadness
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# $XOM Pushes Gulf Refinery During #MarchMadness Ad Blitz, Facility Offered $1.4B Tax Break https://t.co/ZdP0yMLKX3 #FinalFour @NaomiAKlein
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @SenatorTimScott: Congrats to @GamecockMBB on making it to #finalfour! Cheering for @GamecockWBB tonight! #GoGamecocks #MarchMadness htt…
# compound: 0.8065, neg: 0.0, neu: 0.673, pos: 0.327,
# RT @SenatorTimScott: Congrats to @GamecockMBB on making it to #finalfour! Cheering for @GamecockWBB tonight! #GoGamecocks #MarchMadness htt…
# compound: 0.8065, neg: 0.0, neu: 0.673, pos: 0.327,
# RT @WhistleSports: When you perfectly time the #UNC buzzer beater 😱🏀 #MarchMadness
#
# (via:@SamuelGrubbs1 ) https://t.co/Ol2ibpZjB4
# compound: 0.6369, neg: 0.0, neu: 0.756, pos: 0.244,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# North Carolina 💪🏾🏀😎💯#marchmadness
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #MarchMadness moves https://t.co/07ss3RKvj2
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @WhistleSports: When you perfectly time the #UNC buzzer beater 😱🏀 #MarchMadness
#
# (via:@SamuelGrubbs1 ) https://t.co/Ol2ibpZjB4
# compound: 0.6369, neg: 0.0, neu: 0.756, pos: 0.244,
# RT @GatorsOnScout: WATCH: #Gators celebrate OT win over #Badgers in Sweet 16 #MarchMadness https://t.co/m5TFao99nD
# compound: 0.8885, neg: 0.0, neu: 0.512, pos: 0.488,
# RT @TBNSports: The Shot: An oral history of @laettnerbball's swish for the ages.
# @ByBuckyGleason on a #MarchMadness classic: https://t.co/H…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @Ureadyteddy: Turning 9 months old is pretty ballin' 🏀 #FinalFour #marchmadness #basketball #slamdunk #funnybaby #chalkart #babies #newb…
# compound: 0.4939, neg: 0.0, neu: 0.824, pos: 0.176,
# RT @WhistleSports: When you perfectly time the #UNC buzzer beater 😱🏀 #MarchMadness
#
# (via:@SamuelGrubbs1 ) https://t.co/Ol2ibpZjB4
# compound: 0.6369, neg: 0.0, neu: 0.756, pos: 0.244,
# RT @mbohannon4: Feeling some of that #marchmadness with an Elite 8 Bracket warm-up today @USD449
# #PhysEd  https://t.co/W9PnmR2wsv
# compound: 0.128, neg: 0.0, neu: 0.909, pos: 0.091,
# In the thick of #MarchMadness, here are 4 female bball standouts you should know in #251 starting w/ @yesimunique_
# https://t.co/RO91KKnAnK
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #OMSroadTrip NOW 2C NCAA softball California @CalSB vs Stanford @StanfordSball #MarchMadness #Pac12SB https://t.co/6Sn00ZuFSs
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @somma_matt: I had my fill of #marchmadness  excitement last night. The rest of the tournament can just go nice and predictable now 😖
# compound: 0.7184, neg: 0.0, neu: 0.769, pos: 0.231,
# #MSNBC #CNN #CBS #NBC #PBS #WHYN #WBZ #Boston #BostonMarathon #MGH #MarchMadness   #Movies https://t.co/tLllqFnaPL
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# In the thick of #MarchMadness, here are 4 female bball standouts you should know in #251 starting w/ @yesimunique_
# https://t.co/zjUxX2e7kT
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #MSNBC #CNN #CBS #NBC #PBS #WHYN #WBZ #Boston #BostonMarathon #MGH #MarchMadness   #Movies       Excellent movie. 👏… https://t.co/WCOi7myHx6
# compound: 0.5719, neg: 0.0, neu: 0.802, pos: 0.198,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# I'm still so happy @GoHeels won yesterday especially since they beat the #KentuckyWildcats #UNCvsUK #marchmadness #NCAATournament
# compound: 0.8659, neg: 0.0, neu: 0.617, pos: 0.383,
# RT @SenatorTimScott: Congrats to @GamecockMBB on making it to #finalfour! Cheering for @GamecockWBB tonight! #GoGamecocks #MarchMadness htt…
# compound: 0.8065, neg: 0.0, neu: 0.673, pos: 0.327,
# RT @SenatorTimScott: Congrats to @GamecockMBB on making it to #finalfour! Cheering for @GamecockWBB tonight! #GoGamecocks #MarchMadness htt…
# compound: 0.8065, neg: 0.0, neu: 0.673, pos: 0.327,
# $15.99 Hans&amp;Alice Large #yoga #Mat #bag
# https://t.co/bFevdhsd4V   #coupon #exercise #gym enjoy yoga life #marchmadness #shopping #gymlife
# compound: 0.4939, neg: 0.0, neu: 0.824, pos: 0.176,
# RT @MarriottRewards: Dive into #MarchMadness in #MRxSanJose. RT for a chance to win tickets to the big game. Rules: https://t.co/ur15qtl2TT…
# compound: 0.7003, neg: 0.0, neu: 0.746, pos: 0.254,
# Click to edurne please https://t.co/58FWRLCYqR  #mondaymotivation #worldtheatreday #marchmadness
# compound: 0.3182, neg: 0.0, neu: 0.753, pos: 0.247,
# RT @MarriottRewards: Don’t miss a second of the game in #MRxKansasCity! RT to win tickets to #MarchMadness. Rules: https://t.co/ur15qtl2TT…
# compound: 0.5411, neg: 0.074, neu: 0.738, pos: 0.189,
# RT @kidcue: Just wrote new blog: NBA Teams Should Give Tanks.  #marchmadness #NBA #NBADraft #Hawks  https://t.co/uPOExgFUhn
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @TweeturbizUK: #ukbchour Evening ALL our #marchmadness offer is enough to make you clap excitedly......Go on just ask us!!
#
# @EasyShareUK…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @YahooSports: The last time Oregon made the Final Four 78 years ago, Perry Ellis was just a freshman. #MarchMadness https://t.co/GhSu8Yu…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #MarchMadness RT KentuckyMBB RT UKSportsNetwork: Cal says Derek Willis was invited to NABC All-Star game and Portsmouth pre-draft camp.
#
# W…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #MarchMadness RT KentuckyMBB "How about Dom? Dom kept us in the game!"
#
# https://t.co/Z3SXkak7sD https://t.co/8TP0V8QhBN #GoBigBlue #Elite8
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #MarchMadness RT KentuckyMBB "I couldn't be more proud of Isaac. ... He was prepared for his moment."
#
# https://t.co/Z3SXkak7sD …
# compound: -0.2194, neg: 0.134, neu: 0.774, pos: 0.092,
# #MarchMadness RT KentuckyMBB "When you looked at all the stats, you would have thought we won the game." - Coach Cal
#
# …
# compound: 0.5719, neg: 0.0, neu: 0.837, pos: 0.163,
# #MarchMadness RT KentuckyMBB "You saw after the game that they do care. These are great kids." - Coach Cal https://t.co/zybUXRwYPx #GoBigB…
# compound: 0.8074, neg: 0.0, neu: 0.711, pos: 0.289,
# RT @MarriottRewards: Want to cheer your team on in #MRxMemphis? RT for a chance to win tickets to #MarchMadness. Rules: https://t.co/ur15qt…
# compound: 0.8555, neg: 0.0, neu: 0.606, pos: 0.394,
# Could #MarchMadness wreak havoc on your otherwise productive office environment? Learn more https://t.co/25pcjpgcAV https://t.co/iVeevFFRO1
# compound: -0.5994, neg: 0.231, neu: 0.769, pos: 0.0,
# RT @MarriottRewards: Dive into #MarchMadness in #MRxSanJose. RT for a chance to win tickets to the big game. Rules: https://t.co/ur15qtl2TT…
# compound: 0.7003, neg: 0.0, neu: 0.746, pos: 0.254,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @WhistleSports: When you perfectly time the #UNC buzzer beater 😱🏀 #MarchMadness
#
# (via:@SamuelGrubbs1 ) https://t.co/Ol2ibpZjB4
# compound: 0.6369, neg: 0.0, neu: 0.756, pos: 0.244,
# RT @Stockton_CA: #MarchMadness can really fire up an appetite! Here's a list of dining options around the arena - https://t.co/vDN7IOIpIa
# compound: -0.4561, neg: 0.149, neu: 0.851, pos: 0.0,
# Esta es la tabla de posiciones hasta el momento en nuestra competencia del #MarchMadness  🏀 entre el #TeamMadness y… https://t.co/SopDgsvzGC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# @RyanPietrowski #hyper #marchmadness  #🏁 #trapling #tingting #americana
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Only $9.99.Hans&amp;Alice small #yoga #Mat #bag
# https://t.co/HLiCmlrWtr   #coupon #exercise Enjoy yoga life
# #marchmadness #gymlife #shopping
# compound: 0.4939, neg: 0.0, neu: 0.814, pos: 0.186,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Independent testing found dangerous levels of Manhattan Project radioactive waste contamination INSIDE a resident's… https://t.co/mjDPe55V5u
# compound: -0.7096, neg: 0.33, neu: 0.67, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Hey guys #marchmadness
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #UnnecessaryConfessions #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words Raiders true… https://t.co/WsUeW6OuLs
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @peer5: #marchmadness #live #streaming viewership is up 26% y-o-y; 75 million streams in the 1st 5 days: https://t.co/7HQc8mSwe9 https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @TyKellyandChuck: A #FinalFour Song for @dariusrucker! Today's #10MinuteTune from @SBSwags..  #MarchMadness #SouthCarolina https://t.co/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @SportsInsights: Updated #MarchMadness Champion Probabilities
#
# #Gonzaga 51.4%
# #UNC 24.1%
# #Oregon 16%
# #SouthCarolina 8.5%
#
# https://t.co/j…
# compound: 0.5994, neg: 0.0, neu: 0.782, pos: 0.218,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Industry Monday! @BossBarChicago #mondaymotivation #internationalwhiskyday #MarchMadness #spanishpaelladay… https://t.co/nEAOOfYv4P
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Hahahaha, i just checked a bracket I did when I was half asleep and I had 3 of the final 4 right. 😊#marchmadness #FinalFour
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @SportsQuotient: THIS. SEQUENCE. #MarchMadness https://t.co/lXKrhEzDbJ
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #marchmadness has me like 🏀 First time playing hoops since middle school. HORSE skills still on point, three pointe… https://t.co/3BbvcIJVSF
# compound: 0.5106, neg: 0.0, neu: 0.798, pos: 0.202,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Put my city on my back #ATL
#
# New campaign work for @point3hoops #marchmadness @weareunconquered https://t.co/oHZaRlcR5P
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @colbertlateshow: A message from @toonDonaldTrump: My fellow Americans, as you know #MarchMadness is upon us. Gaze in wonder at my treme…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #SpartyOn #marchmadness https://t.co/TO27YZWlu1
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @pizzahut: Our eight are all lined up. Are yours? #MarchMadness https://t.co/1JkhmLSvD9
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @JohnLegere: It's been a crazy weekend of basketball. Question is... Do you think I still have a chance to win? #MarchMadness https://t.…
# compound: 0.5267, neg: 0.095, neu: 0.675, pos: 0.23,
# Watch the NCAA Final Four  https://t.co/4WdrK86EYM  #finalfour #nyc #marchmadness
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Brutal l'efecte #marchmadness https://t.co/vmMiiuCZKX
# compound: -0.6249, neg: 0.577, neu: 0.423, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @DimeUPROXX: Hit the game-winning shot and still made it to his 8 am class. Good on ya, Luke Maye! 👏 #MarchMadness #Tarheels https://t.c…
# compound: 0.4926, neg: 0.0, neu: 0.868, pos: 0.132,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @DJDoubleA336: #MarchMadness #UNC https://t.co/OAbWf9q7lS
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words Raiders true detective https://t.co/eNcnF4n2dj
# compound: 0.4215, neg: 0.0, neu: 0.714, pos: 0.286,
# RT @YahooSports: 10 years ago this week, Barton College pulled off one of the most incredible comebacks you'll ever see. #MarchMadness http…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @DemetricDWarren: Survive &amp; Advance #marchmadness #HeelNation #HeelYes #FinalFour https://t.co/apd1fM116C
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# A hypnotist who makes you forget all your bracket picks. #marchmadness #marchsadness
# compound: -0.2263, neg: 0.16, neu: 0.84, pos: 0.0,
# RT @DVGMPLS: Ajani vs Nissa from #MagicTheGathering is our first matchup of Round 2 in the #marchmadness #geekbracket - Vote your favorite…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @DVGMPLS: First day Round 2 #marchmadness #geekbracket : Ajani vs Nissa! Choose your champion - @wizards_magic #MagicTheGathering
# compound: 0.636, neg: 0.0, neu: 0.77, pos: 0.23,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BBallSociety_: Unbelievable series.
# #MarchMadness https://t.co/FYsvC1oUR9
# compound: 0.2023, neg: 0.0, neu: 0.735, pos: 0.265,
# RT @Ureadyteddy: Turning 9 months old is pretty ballin' 🏀 #FinalFour #marchmadness #basketball #slamdunk #funnybaby #chalkart #babies #newb…
# compound: 0.4939, neg: 0.0, neu: 0.824, pos: 0.176,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @DVGMPLS: Round 2: Kharn the Betrayer vs ... Tacocat?! Vote in our poll below! #marchmadness #geekbracket #explodingkittens #40K https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @IndustryNightIn: Industry Monday! @bellyQchicago @TheBestLoop #mondaymotivation #internationalwhiskyday #spanishpaelladay #MarchMadness…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @DVGMPLS: Kharn the Betrayer from #40K vs Tacocat from #explodingkittens face off in round 2 of our #marchmadness #geekbracket
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @Nashvlkitn: March Madness poll:
#
# Who wins the national championship? #marchmadness #NationalChampionship #NCAA #NationalChamps 🏀
#
# Feel…
# compound: 0.5719, neg: 0.135, neu: 0.558, pos: 0.307,
# RT @SportsQuotient: THIS. SEQUENCE. #MarchMadness https://t.co/lXKrhEzDbJ
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @jhutch1992: Let's go CATS!! Keep it up! #BBN #marchmadness
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @SenatorTimScott: Congrats to @GamecockMBB on making it to #finalfour! Cheering for @GamecockWBB tonight! #GoGamecocks #MarchMadness htt…
# compound: 0.8065, neg: 0.0, neu: 0.673, pos: 0.327,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @ncaabspain: Las derrotas se lloran... Desconsuela ver a Fox y Adebayo así tras el partido
# #marchmadness
# https://t.co/vmMHK2zNGq
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @SenatorTimScott: Congrats to @GamecockMBB on making it to #finalfour! Cheering for @GamecockWBB tonight! #GoGamecocks #MarchMadness htt…
# compound: 0.8065, neg: 0.0, neu: 0.673, pos: 0.327,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Congrats to @GamecockMBB on making it to #finalfour! Cheering for @GamecockWBB tonight! #GoGamecocks #MarchMadness https://t.co/OLiIk0JC6U
# compound: 0.8065, neg: 0.0, neu: 0.641, pos: 0.359,
# RT @RobinRoberts: Next on @GMA..#MarchMadness has provided lots of #MondayMotivation! My @HailStateWBK gear is coming w/ me to Dallas!🏀 htt…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @julietomascik: #Cattle are more than meat. 1 hide = 12 basketballs. #MarchMadness
# compound: -0.2415, neg: 0.164, neu: 0.836, pos: 0.0,
# Lonzo Ball looks like a premature Drake! 😂😂😂 #MarchMadness
# compound: 0.4199, neg: 0.0, neu: 0.715, pos: 0.285,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @JusticeWillett: Judge Neil Gorsuch providing solid color commentary today. #MarchMadness https://t.co/QhJqS67wh5
# compound: 0.1531, neg: 0.0, neu: 0.873, pos: 0.127,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @MissThomasPTHS: 🙌🏼 #peqpantherpride #marchmadness https://t.co/HqiRKFTKIh
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words Raiders true detective https://t.co/iKVYVtm68S
# compound: 0.4215, neg: 0.0, neu: 0.714, pos: 0.286,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# #MarchMadness RT KentuckyMBB "I'm still in pain for these kids." - Coach Cal on his radio show.
#
# https://t.co/Z3SXkak7sD …
# compound: -0.5106, neg: 0.171, neu: 0.829, pos: 0.0,
# Calling all #IvyLeague #Alumni! Join the #marchMadness challenge and help us raise $8K by Saturday night:… https://t.co/zUhWyAjCkb
# compound: 0.6696, neg: 0.0, neu: 0.683, pos: 0.317,
# #MarchMadness RT KentuckyMBB RT UKSportsNetwork: Cal: wish I'd called timeout before final play but realize now probably wouldn't have had …
# compound: 0.3716, neg: 0.0, neu: 0.835, pos: 0.165,
# #MarchMadness RT KentuckyMBB RT UKSportsNetwork: Cal on arrival: "You lose a heartbreaking game and you come home and our fans are still th…
# compound: -0.6908, neg: 0.222, neu: 0.778, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# "Chhill" now available https://t.co/Rydc4UxXyG only $20 more colors on the site!! #marchmadness https://t.co/wgtDXzMiWm
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @NBAenlinea: Felicidad a tristeza en solo un segundo #marchmadness 😂😢 https://t.co/oYA1f4IYMb
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# 🏀 #LALATE 🏀 LAST NIGHT
# #FINALFOUR #BRACKET is now SET!!
# #NCAAtournament #MarchMadness #collegebasketball
# https://t.co/kd36ZG0JDO
#  m
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @RobinRoberts: Next on @GMA..#MarchMadness has provided lots of #MondayMotivation! My @HailStateWBK gear is coming w/ me to Dallas!🏀 htt…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Great game #marchmadness ! Congratulations North Carolina! https://t.co/WNR3GhiCmX
# compound: 0.8619, neg: 0.0, neu: 0.368, pos: 0.632,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @ncaabspain: Las derrotas se lloran... Desconsuela ver a Fox y Adebayo así tras el partido
# #marchmadness
# https://t.co/vmMHK2zNGq
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Technically its bigger....68 teams....some shit like that #marchmadness #FinalFour
# https://t.co/LXGC7wWhci
# compound: -0.2732, neg: 0.255, neu: 0.567, pos: 0.177,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Industry Monday! @bellyQchicago @TheBestLoop #mondaymotivation #internationalwhiskyday #spanishpaelladay… https://t.co/o7AcOkmoiX
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Who's going to win it all in Phoenix #MarchMadness #FinalFour
# compound: 0.5859, neg: 0.0, neu: 0.703, pos: 0.297,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# 🏀 #LALATE 🏀 LAST NIGHT
# #Kentucky UPSET BY #UNC 73-75 final!
# #Elite8 #Bracket 2017: #NCAA #MarchMadness
# https://t.co/kRvOVuk6jc .
# compound: -0.561, neg: 0.206, neu: 0.794, pos: 0.0,
# RT @UofSC: On campus isn't a very quiet place to be right now. 🔥 Go #Gamecocks! #UofSC #FOUReverToThee #MarchMadness #Final4 https://t.co/c…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @WhistleSports: When you perfectly time the #UNC buzzer beater 😱🏀 #MarchMadness
#
# (via:@SamuelGrubbs1 ) https://t.co/Ol2ibpZjB4
# compound: 0.6369, neg: 0.0, neu: 0.756, pos: 0.244,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @TheGarden: .@UofSC fans around the world are READY for @GamecockMBB in the #Elite8 at The Mecca of Basketball! #MarchMadness https://t.…
# compound: 0.5461, neg: 0.0, neu: 0.85, pos: 0.15,
# #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words Raiders true detective https://t.co/pH1bjlG2Em
# compound: 0.4215, neg: 0.0, neu: 0.714, pos: 0.286,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# PKBO submitted 39.47 fps X265 1080P  #MARCHMADNESS https://t.co/HaCUb23aN1
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @sportingnews: South Carolina has been tearing through the NCAA​ Tournament.
#
# Their secret? Frank Martin​'s death stare. 👀 #MarchMadness…
# compound: -0.5994, neg: 0.187, neu: 0.813, pos: 0.0,
# RT @DoveMenCare: It takes skill to win #MarchMadness. But it takes care to be a real winner.
#
# RT to show what #RealStrength looks like. ht…
# compound: 0.9231, neg: 0.0, neu: 0.601, pos: 0.399,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words Raiders true detective https://t.co/MiPh5HDMB9
# compound: 0.4215, neg: 0.0, neu: 0.714, pos: 0.286,
# Incredible emotion and class in that post game interview with #UK #oneanddone players
# @LanceMcAlister #marchmadness #elite8 #Wildcats #ncaa
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Vote for @GoMastodons in this NATIONAL contest! #MarchMadness #FortWayne
#
# https://t.co/rfpxD80uww
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# I'm sure @ATT @DIRECTV will make that happen for you. And me. And us. #marchmadness https://t.co/c4qdJfXHtW
# compound: 0.3182, neg: 0.0, neu: 0.867, pos: 0.133,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @MarvinEAdams: #marchmadness @jca10c9 @marstu67 @GoHeels @GamecockMBB @northcarolina @southcarolina Nothing could be FINER than to be in…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @msPartner: #CRNChannelMadness is on partners! Vote for @Gavriels1 to win!  https://t.co/a1sGR90cPq. #Marchmadness #womenintech #MSPartn…
# compound: 0.658, neg: 0.0, neu: 0.762, pos: 0.238,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# That's 145 games worth. Great players, just off games at the wrong time #MarchMadness #kubball https://t.co/pDo2hSdavV
# compound: 0.4404, neg: 0.14, neu: 0.588, pos: 0.271,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# UNC Game Winner Against UK with Titanic Music = greatness @GaryLazerEyes1 @laurenh2704 😍😍😍 #GDTBATH #MarchMadness https://t.co/wEB9S3jm5Q
# compound: 0.5859, neg: 0.0, neu: 0.787, pos: 0.213,
# RT @PerolasdaNBA: Quando você lembra que hoje já é segunda #MarchMadness
# https://t.co/Pb3vhX7zb3
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: ICYMI: The end of North Carolina/Kentucky was incredible. #MarchMadness https://t.co/m1KNEPU6L7
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @man_cole_B: I call this look the "UNC is gunna win it all" #formal #MarchMadness https://t.co/xGwObzVjtz
# compound: 0.5859, neg: 0.0, neu: 0.787, pos: 0.213,
# RT @RaulOrozco: #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words Raiders true detective https://t.co/upvvisNcZd
# compound: 0.4215, neg: 0.0, neu: 0.763, pos: 0.237,
# RT @JusticeWillett: No joke, this was in my freaky #MarchMadness dream last night. https://t.co/Cx3njaJYs4
# compound: -0.128, neg: 0.249, neu: 0.529, pos: 0.222,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @BurnsAndGambo: Who should @CallMeMaloney be loyal to when it comes to #MarchMadness?
# compound: 0.4767, neg: 0.0, neu: 0.795, pos: 0.205,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @KBDugan: 📷 Relive all the wonderful moments that made the #Gamecocks Final Four bound here: https://t.co/HKXOGdOR80 #MarchMadness https…
# compound: 0.5719, neg: 0.0, neu: 0.821, pos: 0.179,
# #marchmadness followers. You've seen this right?? https://t.co/k1AQYHEluq
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @Ureadyteddy: Turning 9 months old is pretty ballin' 🏀 #FinalFour #marchmadness #basketball #slamdunk #funnybaby #chalkart #babies #newb…
# compound: 0.4939, neg: 0.0, neu: 0.824, pos: 0.176,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @TyKellyandChuck: A #FinalFour Song for @dariusrucker! Today's #10MinuteTune from @SBSwags..  #MarchMadness #SouthCarolina https://t.co/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @WhistleSports: If Gordon Hayward's buzzer beater went in... #MarchMadness https://t.co/b7m6VWV6sV
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @GoDucksJoe: I filled out your bracket for you. #GoDucks #MARCHMADNESS https://t.co/ecxN03lxpS
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @marchmadness: ICYMI: The end of North Carolina/Kentucky was incredible. #MarchMadness https://t.co/m1KNEPU6L7
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: ICYMI: The end of North Carolina/Kentucky was incredible. #MarchMadness https://t.co/m1KNEPU6L7
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# ...
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @DiegoStax1: Who do you got winning it all?
# #NCCAABasketball #marchmadness
# compound: 0.5267, neg: 0.0, neu: 0.746, pos: 0.254,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words https://t.co/cDKoVkc3gS
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @DiegoStax1: Who do you got winning it all?
# #NCCAABasketball #marchmadness
# compound: 0.5267, neg: 0.0, neu: 0.746, pos: 0.254,
# RT @DiegoStax1: Who do you got winning it all?
# #NCCAABasketball #marchmadness
# compound: 0.5267, neg: 0.0, neu: 0.746, pos: 0.254,
# RT @DiegoStax1: Who do you got winning it all?
# #NCCAABasketball #marchmadness
# compound: 0.5267, neg: 0.0, neu: 0.746, pos: 0.254,
# RT @LethalWeaponFOX: When someone at the bar starts talking trash about your #MarchMadness bracket. #LethalWeapon https://t.co/zYfrA7rupm
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @RaulOrozco: #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words https://t.co/1VfWhuWYn1
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #WorldTheatreDay #mondaymotivation #marchmadness #ImproveYourLoveLifeIn5Words https://t.co/DVMQkvHKXg
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Rain, rain go away.... #wet #marchmadness #letthesunshinein
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @girlscangrill: Brisket nachos! Because it's game day! #girlscangrill #marchmadness https://t.co/9VnIqGL9JB
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Don't know who to go with? Let The Shooter pick for you! #Sports #SportsBet #Betting #PropBet #NCAA #MarchMadness… https://t.co/cr8IM4gtyq
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @Greenville_SC: So proud of @GamecockMBB!   Heading to the #FinalFour!  #MarchMadness just got that much better!  Making #yeahTHATgreenv…
# compound: 0.8003, neg: 0.0, neu: 0.691, pos: 0.309,
# RT @takl_app: We'd like to help you #Takl your #weeding - Get 10% off on all weeding jobs through the end of March! #MarchMadness #ChoreMad…
# compound: 0.6696, neg: 0.0, neu: 0.8, pos: 0.2,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# @dannymcgowan Soho House Chicago https://t.co/Wi7LquM4z4 #Consultant #restaurant #chicago #food @sohohouse #fun… https://t.co/A3fvg0wiXr
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @WhistleSports: LaVar Ball after UCLA lost 😂  #MarchMadness https://t.co/rc1KYFKZ9s
# compound: -0.3182, neg: 0.223, neu: 0.777, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @UMKCSBTDC: March is @getshottracker season! @NAIA_News #marchmadness https://t.co/78JNi3j5ho
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# Good luck to @OregonWBB team tonight against UCONN.  #GoDucks #marchmadness
# compound: 0.7096, neg: 0.0, neu: 0.576, pos: 0.424,
# RT @Jrcr7_13: Tar Heels headed to final 4! 2 more games till national champions! Let's go!!!!! #MarchMadness #UNCvsUK
# compound: 0.6776, neg: 0.0, neu: 0.778, pos: 0.222,
# #Nude all day and no cover until 6:30pm @KittensCabaret #Seattle #SeattleArena #Georgetown #ilwu #Boeing #Microsoft… https://t.co/vVhMxIqGOq
# compound: -0.296, neg: 0.128, neu: 0.872, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @LissetteColone: 1248 Store Managers Trevor And Chris,  getting us excited for Leaders Edge! #Leadersedge #Marchmadness🏀🏀  #trendingoran…
# compound: 0.4003, neg: 0.0, neu: 0.856, pos: 0.144,
# RT @NBAenlinea: Felicidad a tristeza en solo un segundo #marchmadness 😂😢 https://t.co/oYA1f4IYMb
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @Aldo_Amato: Kermit Davis' (@MT_CoachDavis) assistant coaches to get hefty raise https://t.co/mOG1v3KdAR via @dnj_com #marchmadness http…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# It's #marchmadness! Join a #winningteam at Jobvite. We are #hiring for a Sr.Technical Product Man...
# https://t.co/KrvqSOuRTe #job
# compound: 0.3595, neg: 0.0, neu: 0.849, pos: 0.151,
# RT @krazykatfreebie: Score BIG in #MarchMadness $250 Cash Giveaway! Win $250 PayPal OR Amazon e-gift Card #Sweet16 Road to the #Finalfour h…
# compound: 0.6996, neg: 0.0, neu: 0.775, pos: 0.225,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @LissetteColone: 1248 Store Managers Trevor And Chris,  getting us excited for Leaders Edge! #Leadersedge #Marchmadness🏀🏀  #trendingoran…
# compound: 0.4003, neg: 0.0, neu: 0.856, pos: 0.144,
# RT @OtanerTech: Working on Monday without any motivation... 👨‍💻😭🤣 #gamedev #indiedev #MondayMorning #mondaymotivation #marchmadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# #Marchmadness https://t.co/Lx3yvbrQln
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @WhistleSports: The internet is a savage place during #MarchMadness 😂
#
# feat. @UofSC @DefPenSports @NOTSportsCenter @marianaa_alfaro http…
# compound: -0.4588, neg: 0.176, neu: 0.824, pos: 0.0,
# RT @NVNewsNetwork: Our 1st tweet is a poll! Please vote &amp; share! Who do you want to win the @cityofhenderson Mayoral Race? #marchmadness #N…
# compound: 0.8475, neg: 0.0, neu: 0.651, pos: 0.349,
# #marchmadness #FinalFour Weird? N. Carolina could play S. Carolina ​for Title? 🏆 Crazy? West powerhouses 😂 Oregon &amp; Gonzaga play for title?🏆
# compound: 0.3939, neg: 0.159, neu: 0.619, pos: 0.223,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @YahooSports: #MarchMadness https://t.co/1cNwumYEwK
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Evening ALL,would anyone like #Free promo for one week followed by 4 weeks half price? costing you just £10 #OneOff #Marchmadness #Offer
# compound: 0.3612, neg: 0.0, neu: 0.889, pos: 0.111,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @ChickfilaBGKY: Slum Dunk opportunity of a lifetime! 3/28/17 2-5pm #Nuggets #marchmadness https://t.co/nskeIpDSFC
# compound: 0.4753, neg: 0.0, neu: 0.781, pos: 0.219,
# RT @NoahsArcFdn: s/o to NAF Coach EJ Ollison hosting successful #MarchMadness tourney @MACCCHICAGO for #Chicago youth 💧✌️ https://t.co/n0zv…
# compound: 0.5859, neg: 0.0, neu: 0.817, pos: 0.183,
# RT @RealAltoids: Whose bracket is about as fucked as the White House? #marchmadness
# compound: -0.6597, neg: 0.268, neu: 0.732, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @ESPNradio941: What was bigger? #marchmadness #NCAATournament
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @POWERADE: Rest is for the rest. @Dame_Lillard #PowerThrough #MarchMadness https://t.co/Zz6UR1GcUA
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @DylansFreshTake: Here is the ending to the crazy Kentucky vs UNC game. This is why I love #MarchMadness https://t.co/Op0Z72rH0j
# compound: 0.4215, neg: 0.102, neu: 0.72, pos: 0.178,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# I know more about College Basketball than you. 🏀 #marchmadness #gozags https://t.co/kU8YsAEOFJ
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @ColeyHarvey: Just spoke to a South Carolina fan who was all smiles. Said: "I've been waiting 44 years for this." #marchmadness https://…
# compound: 0.6597, neg: 0.0, neu: 0.787, pos: 0.213,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @TheEllenShow: Everyone’s mad for #MarchMadness, especially my montage editor. https://t.co/1wpXbeONPL
# compound: -0.4939, neg: 0.242, neu: 0.758, pos: 0.0,
# Let's go @GamecockWBB &amp; @dawnstaley !  Great opportunity tonight to advance to #FinalFour! #roadtoDallas #marchmadness #Gamecocks
# compound: 0.8168, neg: 0.0, neu: 0.635, pos: 0.365,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# 25% OFF SITEWIDE
# #CouponCode: MARCHMADNEZZ
# https://t.co/VWjBGlTZfv
# #marchmadness #supersale #onsalenow https://t.co/DDz84pffQy
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @marchmadness: For Kentucky and North Carolina fans, the end of yesterday's game was a roller-coaster of emotions. #MarchMadness https:/…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# Vegas odds to win the National Championship
#
# 1. Gonzaga 3/2
#
# 2. North Carolina 7/5
#
# 3. Oregon 9/2
#
# 4. South Carolina 15/2
#
# #MarchMadness
# compound: 0.7717, neg: 0.0, neu: 0.749, pos: 0.251,
# RT @NBAenlinea: Felicidad a tristeza en solo un segundo #marchmadness 😂😢 https://t.co/oYA1f4IYMb
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @TwoCsports: #MarchMadness has definitely not disappointed this year. Just how did we get here though?
#
# FULL STORY:
# https://t.co/k7OfUxD…
# compound: 0.6433, neg: 0.0, neu: 0.764, pos: 0.236,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @BleacherReport: And then there were four... #MarchMadness https://t.co/0MbxpgAuUC
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# @CandaceBurnsTV got the best #marchmadness commercials
# compound: 0.6369, neg: 0.0, neu: 0.543, pos: 0.457,
# How Much Does the NCAA Make off March Madness? | #Investopedia #MarchMadness https://t.co/I8CNi1zLS4
# compound: -0.4404, neg: 0.209, neu: 0.791, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# wot in tar heel nation #marchmadness #UKvsUNC https://t.co/rG2vO79eja
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @HowardWKYT: The final seconds of the Kentucky-North Carolina game was an emotional roller coaster for Big Blue fans. #marchmadness #WKY…
# compound: 0.1531, neg: 0.0, neu: 0.926, pos: 0.074,
# RT @NVNewsNetwork: Our 1st tweet is a poll! Please vote &amp; share! Who do you want to win the @cityofhenderson Mayoral Race? #marchmadness #N…
# compound: 0.8475, neg: 0.0, neu: 0.651, pos: 0.349,
# RT @TheNBAMonster: El #marchmadness es así, tiene esta locura...
#
# North Carolina elimina a Kentucky así y va directo al Final Four 👏👏  http…
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# RT @FloridaGators: Congratulations to @GamecockMBB - go win the rest! #SEC #MarchMadness
# compound: 0.8398, neg: 0.0, neu: 0.53, pos: 0.47,
